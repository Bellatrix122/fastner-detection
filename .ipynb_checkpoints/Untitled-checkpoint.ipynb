# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.1 MB/s eta 0:00:00
# ...

# %%
# !unrar x "/content/drive/MyDrive/Data.rar" "/content/drive/MyDrive"
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/Data.rar
#
# Creating    /content/drive/MyDrive/Data                               OK
#   OK
# Creating    /content/drive/MyDrive/Data/images                        OK
# Creating    /content/drive/MyDrive/Data/images/train                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !unzip /content/drive/MyDrive/yolov7.zip -d /content/drive/MyDrive
# Out:
# Archive:  /content/drive/MyDrive/yolov7.zip
#    creating: /content/drive/MyDrive/content/yolov7/
#   inflating: /content/drive/MyDrive/content/yolov7/README.md
#    creating: /content/drive/MyDrive/content/yolov7/wandb/
#    creating: /content/drive/MyDrive/content/yolov7/wandb/run-20260117_055704-zw3isnu8/
#    creating: /content/drive/MyDrive/content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/
#   inflating: /content/drive/MyDrive/content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/wandb-metadata.json
#   inflating: /content/drive/MyDrive/content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/output.log
#   inflating: /content/drive/MyDrive/content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/config.yaml
#   inflating: /content/drive/MyDrive/content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/wandb-summary.json
#    creating: /content/drive/MyDrive/content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/media/
# ...

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 34.45 MiB/s, done.
# Resolving deltas: 100% (511/511), done.
# /content/yolov7

# %%
# %cd /content/yolov7
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7_training.pt
# Out:
# /content/yolov7
# --2026-01-17 08:21:05--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7_training.pt
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/yolov7
# !python train.py --batch 16 --epochs 1 --data /content/drive/MyDrive/Data/dataset.yaml --weights 'yolov7_training.pt' --device 0
# Out:
# /content/yolov7
# 2026-01-17 08:41:59.118197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768639319.138668    8065 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768639319.144964    8065 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768639319.161053    8065 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python detect.py --weights /content/yolov7/runs/train/exp3/weights/best.pt --conf 0.1 --source /content/drive/MyDrive/Data/images/valid/1-100-_jpg.rf.2fce1afaf907a82f9b73144aee7565cf.jpg
# Out:
# Namespace(weights=['/content/yolov7/runs/train/exp3/weights/best.pt'], source='/content/drive/MyDrive/Data/images/valid/1-100-_jpg.rf.2fce1afaf907a82f9b73144aee7565cf.jpg', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.9.0+cu126 CUDA:0 (Tesla T4, 15095.0625MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#displaying yolo7 inference result
import matplotlib.pyplot as plt
import cv2
img = cv2.imread("runs/detect/exp2/1-100-_jpg.rf.2fce1afaf907a82f9b73144aee7565cf.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("Yolo7 Detection Result")
plt.show()

# %%
# !zip -r /content/drive/MyDrive/yolov7.zip /content/yolov7
# Out:
#   adding: content/yolov7/ (stored 0%)
#   adding: content/yolov7/README.md (deflated 75%)
#   adding: content/yolov7/wandb/ (stored 0%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/ (stored 0%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/ (stored 0%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/wandb-metadata.json (deflated 49%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/output.log (deflated 85%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/config.yaml (deflated 73%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/wandb-summary.json (deflated 70%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/media/ (stored 0%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/media/images/ (stored 0%)
#   adding: content/yolov7/wandb/run-20260117_055704-zw3isnu8/files/media/images/Mosaics_0_40f6fc9a08c41ca9b87a.jpg (deflated 2%)
# ...

# %%
from google.colab import files
files.download("/content/yolov7.zip")

# %%
# %cd /content
from ultralytics import YOLO
# Load a model
yolo9_model = YOLO("yolov9c.pt")  # load a pretrained model (recommended for training)
print("Yolo9 Pretrained model loaded")
# Out:
# /content
# ...
# Yolo9 Pretrained model loaded

# %%
results = yolo9_model.train(data="/content/drive/MyDrive/Data/dataset.yaml", epochs=50, imgsz=640)  # train the model
# Out:
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
